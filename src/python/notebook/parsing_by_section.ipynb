# %%
# Data visualization
import matplotlib.pyplot as plt 

# Data manipulation
import pandas as pd
import numpy as np
import csv
from zipfile import ZipFile

# %%
# Webscraping
import glob
import requests
from bs4 import BeautifulSoup
import time
import datetime
from pandas.core.common import flatten
import os
from itertools import chain
from tqdm import tqdm
import json
import urllib.request

# %%
# Parsing and pre-processing
from glob import glob
import os 
import re

from pdfminer.high_level import extract_text
import pdfplumber
from langdetect import detect, DetectorFactory

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize, word_tokenize
from string import punctuation
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %%
import sys
sys.path.append(f'../../python')
from scraper import get_merger_links, download_pdf, get_merger_info, parse_pdf, article_match, article62

# %%
pdf_dir = f"../../../data/pdfs/"
art8_1_pdf_list = glob(os.path.join(pdf_dir, "art8.1/*/*.pdf")) #36
art8_1_pdf_list.sort(key=lambda x: os.path.getctime(x))

art8_2_pdf_list = glob(os.path.join(pdf_dir, "art8.2/*/*.pdf")) #72
art8_2_pdf_list.sort(key=lambda x: os.path.getctime(x))

art8_3_pdf_list = glob(os.path.join(pdf_dir, "art8.3/*/*.pdf")) #14
art8_3_pdf_list.sort(key=lambda x: os.path.getctime(x))

art6_1_pdf_list = glob(os.path.join(pdf_dir, "art6.1/*/*.pdf"))
art6_1_pdf_list.sort(key=lambda x: os.path.getctime(x))

art6_0_pdf_list = glob(os.path.join(pdf_dir, "art6.0/*/*.pdf"))
art6_0_pdf_list.sort(key=lambda x: os.path.getctime(x))

art9_3_pdf_list = glob(os.path.join(pdf_dir, "art9.3/*/*.pdf"))
art9_3_pdf_list.sort(key=lambda x: os.path.getctime(x))

# %%
art6_0_pdf_list
# Out:
# ['../../../data/pdfs/art6.0\\M.10000\\m10000_41_3.pdf',
#  '../../../data/pdfs/art6.0\\M.10011\\m10011_48_3.pdf',
#  '../../../data/pdfs/art6.0\\M.10012\\m10012_75_3.pdf',
#  '../../../data/pdfs/art6.0\\M.10001\\m10001_438_3.pdf',
#  '../../../data/pdfs/art6.0\\M.10003\\m10003_69_3.pdf',
#  '../../../data/pdfs/art6.0\\M.10004\\m10004_67_3.pdf',
#  '../../../data/pdfs/art6.0\\M.10005\\m10005_109_3.pdf',
#  '../../../data/pdfs/art6.0\\M.10010\\m10010_118_3.pdf',
#  '../../../data/pdfs/art6.0\\M.10013\\m10013_79_3.pdf',
#  '../../../data/pdfs/art6.0\\M.10014\\m10014_88_4.pdf',
#  '../../../data/pdfs/art6.0\\M.10019\\m10019_113_3.pdf',
#  '../../../data/pdfs/art6.0\\M.10021\\m10021_69_3.pdf',
#  '../../../data/pdfs/art6.0\\M.10022\\m10022_108_3.pdf',
#  '../../../data/pdfs/art6.0\\M.10023\\m10023_85_3.pdf',
#  '../../../data/pdfs/art6.0\\M.10024\\m10024_136_3.pdf',
#  '../../../data/pdfs/art6.0\\M.10027\\m10027_87_3.pdf',
#  '../../../data/pdfs/art6.0\\M.10028\\m10028_137_3.pdf',
# ...

# %% [markdown]
# # Fix parser by section

# %%
import PyPDF2

# %%
art8_1_pdf_list[0]
# Out:
# '../../../data/pdfs/art8.1\\M.3848\\m3848_20060818_20682_en.pdf'

# %%
with pdfplumber.open(art8_1_pdf_list[0]) as pdf:
    text = []
    subheading = []
    for i in range(len(pdf.pages)):
        # i=i+1
        page = pdf.pages[i]
        page_text = page.extract_text()
        text.append(page_text)

        bold_text = page.filter(lambda obj: obj["object_type"] == "char" and "Bold" in obj["fontname"])
        subheading.append(bold_text.extract_text())
    long_text = ' '.join(text)

    subheading = [x.strip() for x in subheading for x in x.split('\n') if  any(char.isalpha() for char in x.strip())]
    #subheading1 = [x.strip() for x in subheading for x in x.split('\n') if x.strip().isupper()]

# %%
long_text_list = [text.strip() for text in long_text.split('\n') if text.strip()]

# %%
long_text_list
# Out:
# ['EN',
#  'This text is made available for information purposes only.',
#  'A summary of this decision is published in all Community languages in the Official Journal of the',
#  'European Union.',
#  'Case No COMP/M.3848',
#  '–  Sea-Invest/EMO-',
#  'EKOM',
#  'Only the English text is authentic.',
#  'REGULATION (EC) No 139/2004',
#  'MERGER PROCEDURE',
#  'Article 8 (1)',
#  'Date: 18/08/2006',
#  'COMMISSION OF THE EUROPEAN COMMUNITIES',
#  'Brussels, 18/08/2006',
#  'C(2006)3710',
#  'PUBLIC VERSION',
#  'COMMISSION DECISION',
#  'of 18/08/2006',
#  'declaring a concentration to be compatible with the common market',
#  'and the functioning of the EEA Agreement',
#  '(Case No COMP/M.3848 – Sea-Invest/EMO-EKOM)',
#  '1 Commission Decision',
#  'of 18/08/2006',
#  'declaring a concentration to be compatible with the common market',
#  'and the functioning of the EEA Agreement',
#  '(Case No COMP/M.3848 - Sea-Invest / EMO-EKOM)',
#  '(Only the English text is authentic)',
# ...

# %%
subheading
# Out:
# ['Case No COMP/M.3848',
#  '–  Sea-Invest/EMO-',
#  'EKOM',
#  'REGULATION (EC) No 139/2004',
#  'MERGER PROCEDURE',
#  'PUBLIC VERSION',
#  'COMMISSION DECISION',
#  'of 18/08/2006',
#  'declaring a concentration to be compatible with the common market',
#  'and the functioning of the EEA Agreement',
#  'Commission Decision',
#  'of 18/08/2006',
#  'declaring a concentration to be compatible with the common market',
#  'and the functioning of the EEA Agreement',
#  '(Case No COMP/M.3848 - Sea-Invest / EMO-EKOM)',
#  'I.  THE PARTIES',
#  'II.  THE CONCENTRATION',
#  'III.  COMMUNITY DIMENSION',
#  'IV.  RELEVANT MARKETS',
#  'Relevant product market',
#  'Relevant geographic market',
#  'V.  COMPATIBILITY  WITH  THE  COMMON  MARKET  AND  THE  EEA',
#  'AGREEMENT',
#  'A.  Terminal services for coal and iron ore for hinterland traffic',
#  '1.  Article 2(3) of the Merger Regulation',
#  'a)  Unilateral effects',
#  'b)  Coordinated effects',
#  '2.  Article 2(4)',
# ...

# %%
# def find_locations(text, lst):
#     locations = {}
#     for s in lst:
#         indices = []
#         start_index = 0
#         while True:
#             index = text.find(s, start_index)
#             if index == -1:
#                 break
#             indices.append(index)
#             start_index = index + 1
#         locations[s] = indices
#     return locations

# %%
def find_indices(subheading, long_text_list):
    indices = {}
    for elem in subheading:
        indices[elem] = [i for i, x in enumerate(long_text_list) if x and x.find(elem) != -1]
    return indices

# %%
subheading_dict = find_indices(subheading, long_text_list)

# %%
def drop_empty_lists(d):
    return {k: v for k, v in d.items() if len(v)==1}

# %%
subheading_dict = drop_empty_lists(subheading_dict)

# %%
subheading_dict
# Out:
# {'–  Sea-Invest/EMO-': [5],
#  'REGULATION (EC) No 139/2004': [8],
#  'MERGER PROCEDURE': [9],
#  'PUBLIC VERSION': [15],
#  'COMMISSION DECISION': [16],
#  '(Case No COMP/M.3848 - Sea-Invest / EMO-EKOM)': [25],
#  'I.  THE PARTIES': [56],
#  'II.  THE CONCENTRATION': [103],
#  'III.  COMMUNITY DIMENSION': [138],
#  'IV.  RELEVANT MARKETS': [145],
#  'Relevant product market': [146],
#  'Relevant geographic market': [286],
#  'V.  COMPATIBILITY  WITH  THE  COMMON  MARKET  AND  THE  EEA': [715],
#  'AGREEMENT': [716],
#  'A.  Terminal services for coal and iron ore for hinterland traffic': [717],
#  '1.  Article 2(3) of the Merger Regulation': [718],
#  'a)  Unilateral effects': [719],
#  'b)  Coordinated effects': [888],
#  '2.  Article 2(4)': [985],
#  'B.  Terminal services for coal and iron ore for transhipment traffic': [1004],
#  'C.  Conclusion': [1029],
#  'M. Luc Gyselen': [1048],
#  'Fax : +32 2 517 66 03': [1049],
#  'Enforcement Priorities and Decision Scrutiny': [1058],
# ...

# %%
# Initialize start and end variables to extract text between keys
start_index = 0
result = []

# Iterate over the keys in the dictionary and extract the text between them
for key in sorted(subheading_dict, key=subheading_dict.get):
    end_index = (subheading_dict[key])[0]
    # print(end_index[0])
    result.append(long_text_list[start_index:end_index])
    start_index = end_index

# Extract the final text after the last key
result.append(long_text_list[start_index:])

# %%
result
# Out:
# [['EN',
#   'This text is made available for information purposes only.',
#   'A summary of this decision is published in all Community languages in the Official Journal of the',
#   'European Union.',
#   'Case No COMP/M.3848'],
#  ['–  Sea-Invest/EMO-', 'EKOM', 'Only the English text is authentic.'],
#  ['REGULATION (EC) No 139/2004'],
#  ['MERGER PROCEDURE',
#   'Article 8 (1)',
#   'Date: 18/08/2006',
#   'COMMISSION OF THE EUROPEAN COMMUNITIES',
#   'Brussels, 18/08/2006',
#   'C(2006)3710'],
#  ['PUBLIC VERSION'],
#  ['COMMISSION DECISION',
#   'of 18/08/2006',
#   'declaring a concentration to be compatible with the common market',
#   'and the functioning of the EEA Agreement',
#   '(Case No COMP/M.3848 – Sea-Invest/EMO-EKOM)',
#   '1 Commission Decision',
#   'of 18/08/2006',
#   'declaring a concentration to be compatible with the common market',
#   'and the functioning of the EEA Agreement'],
#  ['(Case No COMP/M.3848 - Sea-Invest / EMO-EKOM)',
# ...

# %%
len(result)
# Out:
# 43

# %%
result[7]
# Out:
# ['I.  THE PARTIES',
#  '(3)  Sea-Invest is a privately owned Belgian company which provides terminal services4 in',
#  'a number of ports in Belgium, France, Germany and South Africa. Its core business is',
#  'the handling of dry bulk and other non-containerised cargo. Sea-Invest has a […]∗%',
#  'controlling share5 in Antwerp Bulk Terminal (“ABT”) in Antwerp which provides',
#  'terminal services for coal, iron ore and other dry bulk. Sea-Invest also controls the',
#  'company Sea-Rail N.V. which provides inland transport of minerals by rail from the',
#  'ABT  terminal  in  Antwerp  to  the  industrial  site  of  the  customer.  Sea-Invest  also',
#  'controls  Ghent  Coal  Terminal  (“GCT”)  and  Compagnie  Belge  de  Manutention',
#  '(“CBM”) terminal in Ghent and the Sea-Bulk terminal in Dunkirk, which provide',
#  'terminal services for dry bulk. Furthermore, Sea-Invest owns the company Kleimar',
#  'SA, which operates a fleet of approximately 30 deep sea dry bulk vessels.',
# ...

# %%
# Function to parse pdfs
def parse_pdf(pdf_list):

    df_text = pd.DataFrame(columns = ['article', 'case_num', 'filename', 'text', 'subheading', 'lang'])

    for pdf_file in tqdm(pdf_list):
            article = re.search("art[0-9]+\.[0-9]+", pdf_file).group()
            case_num = re.search("M\.[0-9]{4,5}", pdf_file).group()

            regex = re.compile(r'(?<=/)[^/]+(?=\.pdf)')
            match = regex.search(pdf_file)
            filename = match.group()
            
            try:
                with pdfplumber.open(pdf_file) as pdf:
                    text = []
                    subheading = []
                    for i in range(len(pdf.pages)):
                        page = pdf.pages[i]
                        page_text = page.extract_text()
                        text.append(page_text)

                        bold_text = page.filter(lambda obj: obj["object_type"] == "char" and "Bold" in obj["fontname"])
                        subheading.append(str(re.findall(r'(\d+\.\s.*\n?)+', bold_text.extract_text())).replace('[]', ' '))
                    
                    text = ' '.join(text)
                    lang = detect(text)

                row = pd.DataFrame({'article': article, 'case_num': case_num,'filename': filename,
                                        'text': text, 'subheading': subheading, 'lang': lang}, index=[0])
                df_text = pd.concat([row,df_text.loc[:]]).reset_index(drop=True)
            except (IOError, FileNotFoundError) as ex:
                print("Skipping corrupted PDF file: ", ex)
                pass
            except IndexError:
                print("")
                pass
            # except LangDetectException as ex:
            #     print("Skipping file with LangDetectException: ", ex)
            #     pass          
    return df_text

# %%
text[0]
# Out:
# 'E'

# %%
#--------------------------------------------------------------------------------------------------------------
# Function to parse pdfs by section
def parse_pdf_section(pdf_list):

    df_text = pd.DataFrame(columns = ['article', 'article_txt', 'article_62', 'case_num', 'filename', 'text', 'lang'])

    for pdf_file in tqdm(pdf_list):
            article = re.search("art[0-9]+\.[0-9]+", pdf_file).group()
            case_num = re.search("M\.[0-9]{4,5}", pdf_file).group()

            regex = re.compile(r'(?<=/)[^/]+(?=\.pdf)')
            match = regex.search(pdf_file)
            filename = match.group()
            
            try:
                with pdfplumber.open(pdf_file) as pdf:
                    text = []
                    section_text = ""
                    for i in range(len(pdf.pages)):                    
                        page = pdf.pages[i]
                        page_text = page.extract_text()
                        text.append(page_text)

                        if i == 0:
                            article_txt = article_match(page_text)
                            article_62 = article62(page_text)

                    # join texts by page then detect bold subheadings then split by section
                    text = ' '.join(text)

                     # Split text into sections based on bold subheadings
                    sections = re.findall(r"r'^\s*(\S.*?\S)\s*$'", page_text)
                    for section in sections:
                        if section[1].strip() != "":
                            # If section_text is not empty, create a new row for the previous section
                            if section_text != "":
                                lang = detect(section_text)
                                row = pd.DataFrame({'article': article, 'article_txt': article_txt, 'article_62': article_62, 
                                                    'case_num': case_num,'filename': filename,
                                                    'section_text': section_text.strip(), 'lang': lang}, index=[0])
                                df_text = pd.concat([row,df_text.loc[:]]).reset_index(drop=True)
                                section_text = ""
                            section_text += section[1]

                    # If section_text is not empty, create a new row for the last section
                    if section_text != "":
                        lang = detect(section_text)
                        row = pd.DataFrame({'article': article, 'article_txt': article_txt, 'article_62': article_62, 
                                            'case_num': case_num,'filename': filename,
                                            'section_text': section_text.strip(), 'lang': lang}, index=[0])
                        df_text = pd.concat([row,df_text.loc[:]]).reset_index(drop=True)
                        
            except (IOError, FileNotFoundError) as ex:
                print("Skipping corrupted PDF file: ", ex)
                pass
            # except LangDetectException as ex:
            #     print("Skipping file with LangDetectException: ", ex)
            #     pass          
    return df_text

# %%
parse_pdf_section(art8_1_pdf_list[0:2])
# Out:
# 100%|██████████| 2/2 [00:07<00:00,  3.82s/it]
# Empty DataFrame
# Columns: [article, article_txt, article_62, case_num, filename, text, lang]
# Index: []

# %% [markdown]
# #### Article 8.1 (36 cases)

# %%
df1=parse_pdf(art8_1_pdf_list)
# Out:
# 100%|██████████| 47/47 [08:59<00:00, 11.48s/it]

# %%
# save json file name
date = datetime.date.today().strftime('%Y_%m_%d')

file_name = f"../../../data/parsed/parsed_art8.1_{date}.json"
if os.path.exists(file_name):
    os.remove(file_name)

# save file as json
df1.to_json(file_name)

# %% [markdown]
# #### Article 8.2 (73 cases)

# %%
# create dataframe
df_82 = pd.DataFrame(art8_2_pdf_list, columns = ['pdf_file'])

df_82['id'] = df_82.index
df_82['batch'] = ((df_82['id'])/100).astype(int)

# %%
df_82['batch'].value_counts()
# Out:
# 0    100
# 1     14
# Name: batch, dtype: int64

# %%
# parse pdf
for i in range(0,2): # 0-1
    globals()[f'df_8.2_{i}'] = parse_pdf(tqdm(df_82[df_82['batch']==i]['pdf_file']))
    print("Batch {} completed".format(i))

    # save json file name
    date = datetime.date.today().strftime('%Y_%m_%d')

    file_name = f"../../../data/parsed/parsed_art8.2_batch{i}_{date}.json"
    if os.path.exists(file_name):
        os.remove(file_name)

    # save file as json
    globals()[f'df_8.2_{i}'].to_json(file_name)
# Out:
# ...
#   4%|▍         | 4/100 [01:24<33:54, 21.19s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 3
#       1 # parse pdf
#       2 for i in range(0,2): # 0-1
# ----> 3     globals()[f'df_8.2_{i}'] = parse_pdf(tqdm(df_82[df_82['batch']==i]['pdf_file']))
#       4     print("Batch {} completed".format(i))
#       6     # save json file name
#
# File d:\Desktop\Thesis\predicting-merger-decision-outcomes\src\python\notebook\../../python\scraper.py:261, in parse_pdf(pdf_list)
#     259 for i in range(len(pdf.pages)):
#     260     page = pdf.pages[i]
# --> 261     page_text = page.extract_text()
#     262     text.append(page_text)
#     263 text = ' '.join(text)
#
# File c:\Users\admin\anaconda3\envs\thesis\lib\site-packages\pdfplumber\page.py:329, in Page.extract_text(self, **kwargs)
#     327     return text_layout.to_string()
#     328 else:
# ...

# %% [markdown]
# #### Article 8.3 (13 cases)

# %%
df3 = parse_pdf(art8_3_pdf_list)
# Out:
# 100%|██████████| 14/14 [11:28<00:00, 49.21s/it]

# %%
# save json file name
date = datetime.date.today().strftime('%Y_%m_%d')

file_name = f"../../../data/parsed/parsed_art8.3_{date}.json"
if os.path.exists(file_name):
    os.remove(file_name)

# save file as json
df3.to_json(file_name)

# %% [markdown]
# #### Article 6.1(b)_cc (240 cases)

# %%
# create dataframe
df_61 = pd.DataFrame(art6_1_pdf_list, columns = ['pdf_file'])

df_61['id'] = df_61.index
df_61['batch'] = ((df_61['id'])/100).astype(int)

# %%
df_61['batch'].value_counts()
# Out:
# 0    100
# 1    100
# 2    100
# 3     59
# Name: batch, dtype: int64

# %%
# parse pdf
for i in range(0,4): # 0-3
    globals()[f'df_6.1_{i}'] = parse_pdf(tqdm(df_61[df_61['batch']==i]['pdf_file']))
    print("Batch {} completed".format(i))

    # save json file name
    date = datetime.date.today().strftime('%Y_%m_%d')

    file_name = f"../../../data/parsed/parsed_art6.1_batch{i}_{date}.json"
    if os.path.exists(file_name):
        os.remove(file_name)

    # save file as json
    globals()[f'df_6.1_{i}'].to_json(file_name)
# Out:
# ...
# 100%|██████████| 100/100 [10:03<00:00,  6.03s/it]
# Batch 0 completed
# ...
# 100%|██████████| 100/100 [13:46<00:00,  8.27s/it]
# Batch 1 completed
# ...
# 100%|██████████| 100/100 [12:28<00:00,  7.48s/it]
# Batch 2 completed
# ...
# 100%|██████████| 59/59 [06:51<00:00,  6.97s/it]
# Batch 3 completed

# %% [markdown]
# #### Article 6(b)_uc (5734 cases)

# %%
# create dataframe
df_60 = pd.DataFrame(art6_0_pdf_list, columns = ['pdf_file'])

df_60['id'] = df_60.index
df_60['batch'] = ((df_60['id'])/100).astype(int)

# %%
df_60.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4908 entries, 0 to 4907
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pdf_file  4908 non-null   object
#  1   id        4908 non-null   int64
#  2   batch     4908 non-null   int32
# dtypes: int32(1), int64(1), object(1)
# memory usage: 96.0+ KB

# %%
df_60['batch'].value_counts()
# Out:
# 0     100
# 37    100
# 27    100
# 28    100
# 29    100
# 30    100
# 31    100
# 32    100
# 33    100
# 34    100
# 35    100
# 36    100
# 38    100
# 1     100
# 39    100
# 40    100
# 41    100
# 42    100
# 43    100
# 44    100
# 45    100
# 46    100
# 47    100
# 48    100
# 26    100
# 25    100
# 24    100
# 23    100
# 2     100
# 3     100
# 4     100
# 5     100
# 6     100
# 7     100
# 8     100
# 9     100
# 10    100
# 11    100
# 12    100
# 13    100
# 14    100
# 15    100
# 16    100
# 17    100
# 18    100
# 19    100
# 20    100
# 21    100
# 22    100
# 49      8
# Name: batch, dtype: int64

# %%
# parse pdf
for i in range(0,50): #0-49
    globals()[f'df_6.0_{i}'] = parse_pdf(tqdm(df_60[df_60['batch']==i]['pdf_file']))
    print("Batch {} completed".format(i))

    # save json file name
    date = datetime.date.today().strftime('%Y_%m_%d')

    file_name = f"../../../data/parsed/parsed_art6.0_batch{i}_{date}.json"
    if os.path.exists(file_name):
        os.remove(file_name)

    # save file as json
    globals()[f'df_6.0_{i}'].to_json(file_name)
# Out:
# ...
# 100%|██████████| 100/100 [01:25<00:00,  1.18it/s]
# Batch 0 completed
# ...
# 100%|██████████| 100/100 [01:38<00:00,  1.02it/s]
# Batch 1 completed
# ...
# 100%|██████████| 100/100 [01:04<00:00,  1.55it/s]
# Batch 2 completed
# ...
# 100%|██████████| 100/100 [03:36<00:00,  2.17s/it]
# Batch 3 completed
# ...
# 100%|██████████| 100/100 [02:26<00:00,  1.46s/it]
# Batch 4 completed
# ...
# 100%|██████████| 100/100 [02:50<00:00,  1.70s/it]
# Batch 5 completed
# ...
# 100%|██████████| 100/100 [02:21<00:00,  1.41s/it]
# Batch 6 completed
# ...
# 100%|██████████| 100/100 [01:32<00:00,  1.08it/s]
# Batch 7 completed
# ...
# 100%|██████████| 100/100 [01:28<00:00,  1.13it/s]
# Batch 8 completed
# ...
# 100%|██████████| 100/100 [00:44<00:00,  2.25it/s]
# Batch 9 completed
# ...
# 100%|██████████| 100/100 [00:52<00:00,  1.92it/s]
# Batch 10 completed
# ...
# 100%|██████████| 100/100 [01:45<00:00,  1.06s/it]
# Batch 11 completed
# ...
# 100%|██████████| 100/100 [00:58<00:00,  1.70it/s]
# Batch 12 completed
# ...
# 100%|██████████| 100/100 [01:00<00:00,  1.65it/s]
# ...

# %%
# parse pdf
for i in range(23,50): #0-49
    globals()[f'df_6.0_{i}'] = parse_pdf(tqdm(df_60[df_60['batch']==i]['pdf_file']))
    print("Batch {} completed".format(i))

    # save json file name
    date = datetime.date.today().strftime('%Y_%m_%d')

    file_name = f"../../../data/parsed/parsed_art6.0_batch{i}_{date}.json"
    if os.path.exists(file_name):
        os.remove(file_name)

    # save file as json
    globals()[f'df_6.0_{i}'].to_json(file_name)
# Out:
#  41%|████      | 41/100 [00:45<00:45,  1.30it/s]
# Skipping corrupted PDF file:  [Errno 2] No such file or directory: '../../../data/pdfs/art6.0\\M.10261\\m10261_55_3.pdf'
# ...
# 100%|██████████| 100/100 [01:39<00:00,  1.00it/s]
# Batch 23 completed
# ...
# 100%|██████████| 100/100 [01:25<00:00,  1.16it/s]
# Batch 24 completed
# ...
# 100%|██████████| 100/100 [01:05<00:00,  1.52it/s]
# Batch 25 completed
# ...
# 100%|██████████| 100/100 [01:27<00:00,  1.14it/s]
# Batch 26 completed
# ...
# 100%|██████████| 100/100 [01:47<00:00,  1.07s/it]
# Batch 27 completed
# ...
# 100%|██████████| 100/100 [00:55<00:00,  1.82it/s]
# Batch 28 completed
# ...
# 100%|██████████| 100/100 [01:23<00:00,  1.20it/s]
# Batch 29 completed
# ...
# 100%|██████████| 100/100 [01:10<00:00,  1.41it/s]
# Batch 30 completed
# ...
# 100%|██████████| 100/100 [01:28<00:00,  1.13it/s]
# Batch 31 completed
# ...
# 100%|██████████| 100/100 [01:29<00:00,  1.11it/s]
# Batch 32 completed
# ...
# 100%|██████████| 100/100 [01:42<00:00,  1.03s/it]
# Batch 33 completed
# ...

# %%
df_60.tail
# Out:
# <bound method NDFrame.tail of                                                pdf_file    id  batch
# 0     ../../../data/pdfs/art6.0\M.10000\m10000_41_3.pdf     0      0
# 1     ../../../data/pdfs/art6.0\M.10001\m10001_438_3...     1      0
# 2     ../../../data/pdfs/art6.0\M.10003\m10003_69_3.pdf     2      0
# 3     ../../../data/pdfs/art6.0\M.10004\m10004_67_3.pdf     3      0
# 4     ../../../data/pdfs/art6.0\M.10005\m10005_109_3...     4      0
# ...                                                 ...   ...    ...
# 1242    ../../../data/pdfs/art6.0\M.9994\m9994_81_3.pdf  1242     12
# 1243   ../../../data/pdfs/art6.0\M.9995\m9995_148_3.pdf  1243     12
# 1244   ../../../data/pdfs/art6.0\M.9996\m9996_114_3.pdf  1244     12
# 1245    ../../../data/pdfs/art6.0\M.9998\m9998_51_3.pdf  1245     12
# 1246   ../../../data/pdfs/art6.0\M.9999\m9999_110_3.pdf  1246     12
#
# [1247 rows x 3 columns]>

# %%
df_60[df_60['id']==2341]
# Out:
#                                                pdf_file    id  batch
# 2341  ../../../data/pdfs/art6.0\M.10261\m10261_55_3.pdf  2341     23

# %%
df_60[df_60['pdf_file']=="../../../data/pdfs/art6.0\M.9935\m9935_130_3.pdf"]
# Out:
#                                               pdf_file    id  batch
# 1199  ../../../data/pdfs/art6.0\M.9935\m9935_130_3.pdf  1199     11

# %% [markdown]
# #### Article 9.3 (129 cases)

# %%
# create dataframe
df_93 = pd.DataFrame(art9_3_pdf_list, columns = ['pdf_file'])

df_93['id'] = df_93.index
df_93['batch'] = ((df_93['id'])/100).astype(int)

# %%
df_93['batch'].value_counts()
# Out:
# 0    100
# 1     93
# Name: batch, dtype: int64

# %%
# parse pdf
for i in range(1,2): #0-1
    globals()[f'df_9.3_{i}'] = parse_pdf(tqdm(df_93[df_93['batch']==i]['pdf_file']))
    print("Batch {} completed".format(i))

    # save json file name
    date = datetime.date.today().strftime('%Y_%m_%d')

    file_name = f"../../../data/parsed/parsed_art9.3_batch{i}_{date}.json"
    if os.path.exists(file_name):
        os.remove(file_name)

    # save file as json
    globals()[f'df_9.3_{i}'].to_json(file_name)
# Out:
# ...
# 100%|██████████| 93/93 [09:54<00:00,  6.39s/it]
# Batch 1 completed

# %% [markdown]
# # Append all dataframes

# %%
import glob
import os 

path = f"../../../data/parsed/*.json"
files = glob.glob(path)

# %%
data_merged = pd.concat([pd.read_json(f) for f in files])

# %%
data_merged=data_merged.reset_index(drop=True)

# %%
data_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5635 entries, 0 to 5634
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   article   5635 non-null   object
#  1   case_num  5635 non-null   object
#  2   filename  5635 non-null   object
#  3   text      5635 non-null   object
#  4   lang      5635 non-null   object
# dtypes: object(5)
# memory usage: 220.2+ KB

# %%
data_merged['article'].value_counts()
# Out:
# art6.0    4908
# art6.1     359
# art9.3     193
# art8.2     114
# art8.1      47
# art8.3      14
# Name: article, dtype: int64

# %%
# save json file name
date = datetime.date.today().strftime('%Y_%m_%d')

file_name = f"../../../data/processed/data_merged_{date}.json"
if os.path.exists(file_name):
    os.remove(file_name)

# save file as json
data_merged.to_json(file_name)

# %%
data_merged['lang'].value_counts()
# Out:
# en    5623
# fr       5
# de       4
# sv       2
# es       1
# Name: lang, dtype: int64

# %%
data_merged.head()
# Out:
#   article case_num                   filename  \
# 0  art6.0   M.9004   art6.0\M.9004\m9004_65_3
# 1  art6.0   M.9001   art6.0\M.9001\m9001_54_3
# 2  art6.0   M.9000  art6.0\M.9000\m9000_104_3
# 3  art6.0   M.8999   art6.0\M.8999\m8999_63_8
# 4  art6.0   M.8998   art6.0\M.8998\m8998_71_3
#
#                                                 text lang
# 0   \nEUROPEAN COMMISSION \nDG Competition \n \n ...   en
# 1   \nEUROPEAN COMMISSION \nDG Competition \n \n ...   en
# 2   \n \nEUROPEAN COMMISSION \nDG Competition \n ...   en
# 3   \nEUROPEAN COMMISSION \nDG Competition \n \n ...   en
# 4   \nEUROPEAN COMMISSION \nDG Competition \n \n ...   en

# %%
data_merged[data_merged['case_num'] == "M.10261"]
# Out:
# Empty DataFrame
# Columns: [article, case_num, filename, text, lang]
# Index: []

# %%
data_merged['case_num'][1244]
# Out:
# 'M.5183'

# %%
print(data_merged['text'][1246])
# Out:
# EN
# Case No COMP/M.5181 (cid:150)
# Delta Air Lines/ Northwest
# Airlines
# Only the English text is available and authentic.
# REGULATION (EC) No 139/2004
# MERGER PROCEDURE
# Article 6(1)(b) NON-OPPOSITION
# Date: 06/08/2008
# In electronic form on the EUR-Lex website under document
# number 32008M5181
# Office for Official Publications of the European Communities
# L-2985 Luxembourg COMMISSION OF THE EUROPEAN COMMUNITIES
# Brussels, 06-VIII-2008
# SG-Greffe (2008) D/205034
# C(2008) 4359
# In the published version of this decision, some PUBLIC VERSION
# information has been omitted pursuant to Article
# 17(2) of Council Regulation (EC) No 139/2004
# concerning  non-disclosure  of  business  secrets
# and  other  confidential  information.  The
# MERGER PROCEDURE
# omissions are shown thus [(cid:133)]. Where possible
# the information omitted has been replaced by ARTICLE 6(1)(b) DECISION
# ranges of figures or a general description.
# To the notifying party:
# Dear Sir/ Madam,
# ...
