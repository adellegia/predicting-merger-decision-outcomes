# %%
# Data visualization
import matplotlib.pyplot as plt

# Data manipulation
import pandas as pd
import numpy as np

import glob, re, os, sys, random
from random import shuffle
import random
from time import time

# Vector representations and embeddings
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
import gensim

# Modeling - Logistic, XGBOOST, SVM
from sklearn.model_selection import GridSearchCV, train_test_split, StratifiedShuffleSplit
from sklearn.preprocessing import LabelEncoder

from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler

from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC

from sklearn.model_selection import cross_val_predict, cross_val_score
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, precision_score, recall_score, f1_score
from sklearn.metrics import classification_report, confusion_matrix, precision_recall_fscore_support

from sklearn.pipeline import Pipeline, FeatureUnion

from xgboost import XGBClassifier
import pickle

# %%
import sys
sys.path.append(f'../../../python')

from balance_split_data import create_label, retain_section, balance_unique_id, \
create_balanced_excluded, create_train_test_excluded, group_by_case, create_feature_label

from grid_search import gridsearch, fit_best_model_train, evaluate, fit_best_model_test, get_feature_importance_cv

from ml_model import train_model_cross_val, train_model_test, \
get_feature_importance, get_feature_importance10

# %% [markdown]
# ### Load data

# %%
df = pd.read_json(r"../../../../data/processed/pre-processed_merged_2023_04_03.json")

# %% [markdown]
# #### Loop creation of train and test sets by section

# %%
label_name = "wc"
section_dict={0:'Parties & Operation', 1:'Concentration & Dimension', 
              2:'Market Definition', 3:'Competitive Assessment'}
random_seed=42
random_state=42

# %%
# Loop by section and WC
for section_key in section_dict.keys():
    df1 = create_label(df, label_name)
    df1 = retain_section(df1, section=section_dict[section_key])
    print(df1['section_fin'].value_counts())
    df_unique = balance_unique_id(df1)
    df_balanced_unique, df_balanced, df_excluded = create_balanced_excluded(df_unique, df1, random_seed=random_seed)
    df_train, df_test, df_test1 = create_train_test_excluded(df_balanced, df_balanced_unique, df_excluded, random_state=random_state)
    globals()[f"df_train_grouped_{section_key}"], globals()[f"df_test_grouped_{section_key}"], \
    globals()[f"df_test1_grouped_{section_key}"], globals()[f"df_excluded_grouped_{section_key}"] = group_by_case(df_train, df_test, df_test1, df_excluded)

    globals()[f"X_train_{section_key}"], globals()[f"y_train_{section_key}"], globals()[f"X_test_{section_key}"], globals()[f"y_test_{section_key}"], \
    globals()[f"X_test1_{section_key}"], globals()[f"y_test1_{section_key}"], globals()[f"X_test2_{section_key}"], globals()[f"y_test2_{section_key}"] = create_feature_label(globals()[f"df_train_grouped_{section_key}"],
                                                                                                                                                            globals()[f"df_test_grouped_{section_key}"],
                                                                                                                                                            globals()[f"df_test1_grouped_{section_key}"],
                                                                                                                                                            globals()[f"df_excluded_grouped_{section_key}"])
# Out:
# Parties & Operation    1436
# Name: section_fin, dtype: int64
# Total decisions: 1435
# 0    1219
# 1     216
# Name: label, dtype: int64
# Balancing...
# Total decisions: 432
# Labels distribution:
#  0    216
# 1    216
# Name: 0, dtype: int64
# Training set shape: (345,) (345,)
# Test set shape: (87,) (87,)
# Creating df_train 1: 173 0: 172
# Creating df_test1 1: 43 0: 44
# Creating df_test concatenated with df_excluded with len: 1003
# Creating df_test 1: 43 0: 1047
# Grouping df_train by case_num 1: 173 0: 172
# Grouping df_test by case_num 1: 43 0: 1047
# Grouping df_test1 by case_num 1: 43 0: 44
# Grouping df_excluded by case_num with len: 1003
# Concentration & Dimension    1532
# Name: section_fin, dtype: int64
# Total decisions: 1532
# 0    1294
# 1     238
# Name: label, dtype: int64
# Balancing...
# Total decisions: 476
# Labels distribution:
#  1    238
# 0    238
# Name: 0, dtype: int64
# Training set shape: (380,) (380,)
# Test set shape: (96,) (96,)
# Creating df_train 1: 189 0: 190
# Creating df_test1 1: 48 0: 48
# Creating df_test concatenated with df_excluded with len: 1056
# Creating df_test 1: 48 0: 1104
# Grouping df_train by case_num 1: 189 0: 190
# Grouping df_test by case_num 1: 48 0: 1104
# Grouping df_test1 by case_num 1: 48 0: 48
# Grouping df_excluded by case_num with len: 1056
# Market Definition    1044
# Name: section_fin, dtype: int64
# Total decisions: 1044
# 0    865
# 1    179
# Name: label, dtype: int64
# Balancing...
# Total decisions: 358
# Labels distribution:
#  1    179
# 0    179
# Name: 0, dtype: int64
# Training set shape: (286,) (286,)
# Test set shape: (72,) (72,)
# Creating df_train 1: 142 0: 143
# Creating df_test1 1: 36 0: 36
# Creating df_test concatenated with df_excluded with len: 686
# Creating df_test 1: 36 0: 722
# Grouping df_train by case_num 1: 142 0: 143
# Grouping df_test by case_num 1: 36 0: 722
# Grouping df_test1 by case_num 1: 36 0: 36
# Grouping df_excluded by case_num with len: 686
# Competitive Assessment    1322
# Name: section_fin, dtype: int64
# Total decisions: 1322
# 0    1114
# 1     208
# Name: label, dtype: int64
# Balancing...
# Total decisions: 416
# Labels distribution:
#  0    208
# 1    208
# Name: 0, dtype: int64
# Training set shape: (332,) (332,)
# Test set shape: (84,) (84,)
# Creating df_train 1: 166 0: 166
# Creating df_test1 1: 42 0: 42
# Creating df_test concatenated with df_excluded with len: 906
# Creating df_test 1: 42 0: 948
# Grouping df_train by case_num 1: 166 0: 166
# Grouping df_test by case_num 1: 42 0: 948
# Grouping df_test1 by case_num 1: 42 0: 42
# Grouping df_excluded by case_num with len: 906

# %% [markdown]
# ### Model training (with 10-fold CV) using best parameters from GridSearch

# %%
# for param_name in sorted(parameters.keys()):
#         print("\t%s: %r" % (param_name, best_parameters[param_name]))

# clf__C: 1
# tfidf__binary: True
# tfidf__max_df: 0.025
# tfidf__ngram_range: (2, 2)
# tfidf__norm: 'l1'
# tfidf__use_idf: False
# Out:
# 	clf__C: 1
# 	tfidf__binary: True
# 	tfidf__max_df: 0.025
# 	tfidf__ngram_range: (2, 2)
# 	tfidf__norm: 'l1'
# 	tfidf__use_idf: False

# %%
vec = ('wordvec', TfidfVectorizer(analyzer = 'word', max_features=5000, stop_words='english', ngram_range = (2,2), binary = True, max_df = 0.05, norm = 'l1', use_idf = False))
c = 1
# solver = 'liblinear'
model=LinearSVC(C=c)

# %%
df_metrics = pd.DataFrame(columns = ['set', 'section', 'tn', 'fp', 'fn', 'tp', 'recall', 'precision', 'f_score', 'fpr', 'accuracy', 'roc_auc'])

# %%
for section_key in section_dict.keys():
    # balanced train
    globals()[f"pipeline_train_{section_key}"], globals()[f"trained_model_{section_key}"], globals()[f"y_predict_train_{section_key}"] = train_model_cross_val(globals()[f"X_train_{section_key}"], globals()[f"y_train_{section_key}"], vec=vec, model=model, cv=10)
    globals()[f"df_features_train_{section_key}"], _, _ = get_feature_importance(globals()[f"trained_model_{section_key}"], globals()[f"pipeline_train_{section_key}"])
    metrics_train=evaluate(globals()[f"y_train_{section_key}"],globals()[f"y_predict_train_{section_key}"])
    set = "balanced train"
    section = section_dict[section_key]
    row_train = pd.DataFrame({'set':set, 'section':section, 'tn':metrics_train[0], 'fp':metrics_train[1], 'fn':metrics_train[2], 'tp':metrics_train[3], \
                        'recall':metrics_train[4], 'precision':metrics_train[5], 'f_score':metrics_train[6], \
                        'fpr':metrics_train[7], 'accuracy':metrics_train[8], 'roc_auc':metrics_train[9]}, index=[0])
    
    # balanced test
    _, globals()[f"y_predict_test1_{section_key}"] = train_model_test(globals()[f"X_train_{section_key}"], globals()[f"y_train_{section_key}"], \
                                                     globals()[f"X_test1_{section_key}"], globals()[f"y_test1_{section_key}"], model=model, vec=vec)
    metrics_test1=evaluate(globals()[f"y_test1_{section_key}"],globals()[f"y_predict_test1_{section_key}"])
    set = "balanced test"
    row_test1 = pd.DataFrame({'set':set, 'section':section, 'tn':metrics_test1[0], 'fp':metrics_test1[1], 'fn':metrics_test1[2], 'tp':metrics_test1[3], \
                        'recall':metrics_test1[4], 'precision':metrics_test1[5], 'f_score':metrics_test1[6], \
                        'fpr':metrics_test1[7], 'accuracy':metrics_test1[8], 'roc_auc':metrics_test1[9]}, index=[0])
    
    # imbalanced test
    _, globals()[f"y_predict_test_{section_key}"] = train_model_test(globals()[f"X_train_{section_key}"], globals()[f"y_train_{section_key}"], \
                                                     globals()[f"X_test_{section_key}"], globals()[f"y_test_{section_key}"], model=model, vec=vec)
    metrics_test=evaluate(globals()[f"y_test_{section_key}"],globals()[f"y_predict_test_{section_key}"])
    set = "imbalanced test"
    row_test = pd.DataFrame({'set':set, 'section':section, 'tn':metrics_test[0], 'fp':metrics_test[1], 'fn':metrics_test[2], 'tp':metrics_test[3], \
                        'recall':metrics_test[4], 'precision':metrics_test[5], 'f_score':metrics_test[6], \
                        'fpr':metrics_test[7], 'accuracy':metrics_test[8], 'roc_auc':metrics_test[9]}, index=[0])

    df_metrics = pd.concat([df_metrics.loc[:], row_train, row_test1, row_test]).reset_index(drop=True)

df_metrics['n'] = df_metrics['tn'] + df_metrics['fp'] + df_metrics['fn'] + df_metrics['tp']
# Out:
# ***10-fold cross-validation***
# Accuracy: 0.6434782608695652
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.64      0.65      0.65       172
#            1       0.65      0.64      0.64       173
#
#     accuracy                           0.64       345
#    macro avg       0.64      0.64      0.64       345
# weighted avg       0.64      0.64      0.64       345
#
#
# CR: (0.6435294117647059, 0.6435004704933459, 0.6434662790599979, None)
#
# Confusion matrix:
#  [[112  60]
#  [ 63 110]]
#
# _______________________
#
#
#  Accuracy: 64.348
#  Precision: 0.647
#  Recall: 0.636
#  F1: 0.641
#  FPR: 0.349
#  ROC_AUC: 0.644
# Accuracy: 0.6434782608695652
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.64      0.65      0.65       172
#            1       0.65      0.64      0.64       173
#
#     accuracy                           0.64       345
#    macro avg       0.64      0.64      0.64       345
# weighted avg       0.64      0.64      0.64       345
#
#
# CR: (0.6435294117647059, 0.6435004704933459, 0.6434662790599979, None)
#
# Confusion matrix:
#  [[112  60]
#  [ 63 110]]
#
# _______________________
#
#
# Recall: 0.636
#  Precision: 0.647
#  F1: 0.641
#  FPR: 0.349
#  Accuracy: 64.348
#  ROC_AUC: 0.644
# ***testing on test set***
# Accuracy: 0.6896551724137931
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.70      0.68      0.69        44
#            1       0.68      0.70      0.69        43
#
#     accuracy                           0.69        87
#    macro avg       0.69      0.69      0.69        87
# weighted avg       0.69      0.69      0.69        87
#
#
# CR: (0.6897463002114165, 0.6897463002114165, 0.6896551724137931, None)
#
# Confusion matrix:
#  [[30 14]
#  [13 30]]
#
# _______________________
#
#
#  Accuracy: 68.966
#  Precision: 0.682
#  Recall: 0.698
#  F1: 0.690
#  FPR: 0.318
#  ROC_AUC: 0.690
# Accuracy: 0.6896551724137931
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.70      0.68      0.69        44
#            1       0.68      0.70      0.69        43
#
#     accuracy                           0.69        87
#    macro avg       0.69      0.69      0.69        87
# weighted avg       0.69      0.69      0.69        87
#
#
# CR: (0.6897463002114165, 0.6897463002114165, 0.6896551724137931, None)
#
# Confusion matrix:
#  [[30 14]
#  [13 30]]
#
# _______________________
#
#
# Recall: 0.698
#  Precision: 0.682
#  F1: 0.690
#  FPR: 0.318
#  Accuracy: 68.966
#  ROC_AUC: 0.690
# ***testing on test set***
# Accuracy: 0.6266055045871559
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.62      0.76      1047
#            1       0.07      0.70      0.13        43
#
#     accuracy                           0.63      1090
#    macro avg       0.53      0.66      0.45      1090
# weighted avg       0.94      0.63      0.74      1090
#
#
# CR: (0.5256175987308063, 0.6606805712889541, 0.44544239728690166, None)
#
# Confusion matrix:
#  [[653 394]
#  [ 13  30]]
#
# _______________________
#
#
#  Accuracy: 62.661
#  Precision: 0.071
#  Recall: 0.698
#  F1: 0.128
#  FPR: 0.376
#  ROC_AUC: 0.661
# Accuracy: 0.6266055045871559
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.62      0.76      1047
#            1       0.07      0.70      0.13        43
#
#     accuracy                           0.63      1090
#    macro avg       0.53      0.66      0.45      1090
# weighted avg       0.94      0.63      0.74      1090
#
#
# CR: (0.5256175987308063, 0.6606805712889541, 0.44544239728690166, None)
#
# Confusion matrix:
#  [[653 394]
#  [ 13  30]]
#
# _______________________
#
#
# Recall: 0.698
#  Precision: 0.071
#  F1: 0.128
#  FPR: 0.376
#  Accuracy: 62.661
#  ROC_AUC: 0.661
# ***10-fold cross-validation***
# Accuracy: 0.5631578947368421
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.57      0.53      0.55       190
#            1       0.56      0.60      0.58       190
#
#     accuracy                           0.56       380
#    macro avg       0.56      0.56      0.56       380
# weighted avg       0.56      0.56      0.56       380
#
#
# CR: (0.5635026737967914, 0.5631578947368421, 0.5625641452386897, None)
#
# Confusion matrix:
#  [[100  90]
#  [ 76 114]]
#
# _______________________
#
#
#  Accuracy: 56.316
#  Precision: 0.559
#  Recall: 0.600
#  F1: 0.579
#  FPR: 0.474
#  ROC_AUC: 0.563
# Accuracy: 0.5631578947368421
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.57      0.53      0.55       190
#            1       0.56      0.60      0.58       190
#
#     accuracy                           0.56       380
#    macro avg       0.56      0.56      0.56       380
# weighted avg       0.56      0.56      0.56       380
#
#
# CR: (0.5635026737967914, 0.5631578947368421, 0.5625641452386897, None)
#
# Confusion matrix:
#  [[100  90]
#  [ 76 114]]
#
# _______________________
#
#
# Recall: 0.600
#  Precision: 0.559
#  F1: 0.579
#  FPR: 0.474
#  Accuracy: 56.316
#  ROC_AUC: 0.563
# ***testing on test set***
# Accuracy: 0.5625
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.56      0.60      0.58        48
#            1       0.57      0.52      0.54        48
#
#     accuracy                           0.56        96
#    macro avg       0.56      0.56      0.56        96
# weighted avg       0.56      0.56      0.56        96
#
#
# CR: (0.5629370629370629, 0.5625, 0.5617391304347825, None)
#
# Confusion matrix:
#  [[29 19]
#  [23 25]]
#
# _______________________
#
#
#  Accuracy: 56.250
#  Precision: 0.568
#  Recall: 0.521
#  F1: 0.543
#  FPR: 0.396
#  ROC_AUC: 0.563
# Accuracy: 0.5625
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.56      0.60      0.58        48
#            1       0.57      0.52      0.54        48
#
#     accuracy                           0.56        96
#    macro avg       0.56      0.56      0.56        96
# weighted avg       0.56      0.56      0.56        96
#
#
# CR: (0.5629370629370629, 0.5625, 0.5617391304347825, None)
#
# Confusion matrix:
#  [[29 19]
#  [23 25]]
#
# _______________________
#
#
# Recall: 0.521
#  Precision: 0.568
#  F1: 0.543
#  FPR: 0.396
#  Accuracy: 56.250
#  ROC_AUC: 0.563
# ***testing on test set***
# Accuracy: 0.5980902777777778
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.60      0.74      1104
#            1       0.05      0.52      0.10        48
#
#     accuracy                           0.60      1152
#    macro avg       0.51      0.56      0.42      1152
# weighted avg       0.93      0.60      0.71      1152
#
#
# CR: (0.5101422735596562, 0.5611413043478262, 0.41947554536816634, None)
#
# Confusion matrix:
#  [[664 440]
#  [ 23  25]]
#
# _______________________
#
#
#  Accuracy: 59.809
#  Precision: 0.054
#  Recall: 0.521
#  F1: 0.097
#  FPR: 0.399
#  ROC_AUC: 0.561
# Accuracy: 0.5980902777777778
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.60      0.74      1104
#            1       0.05      0.52      0.10        48
#
#     accuracy                           0.60      1152
#    macro avg       0.51      0.56      0.42      1152
# weighted avg       0.93      0.60      0.71      1152
#
#
# CR: (0.5101422735596562, 0.5611413043478262, 0.41947554536816634, None)
#
# Confusion matrix:
#  [[664 440]
#  [ 23  25]]
#
# _______________________
#
#
# Recall: 0.521
#  Precision: 0.054
#  F1: 0.097
#  FPR: 0.399
#  Accuracy: 59.809
#  ROC_AUC: 0.561
# ***10-fold cross-validation***
# Accuracy: 0.6853146853146853
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.84      0.46      0.59       143
#            1       0.63      0.91      0.74       143
#
#     accuracy                           0.69       286
#    macro avg       0.73      0.69      0.67       286
# weighted avg       0.73      0.69      0.67       286
#
#
# CR: (0.7317311808230906, 0.6853146853146853, 0.6687258687258687, None)
#
# Confusion matrix:
#  [[ 66  77]
#  [ 13 130]]
#
# _______________________
#
#
#  Accuracy: 68.531
#  Precision: 0.628
#  Recall: 0.909
#  F1: 0.743
#  FPR: 0.538
#  ROC_AUC: 0.685
# Accuracy: 0.6853146853146853
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.84      0.46      0.59       143
#            1       0.63      0.91      0.74       143
#
#     accuracy                           0.69       286
#    macro avg       0.73      0.69      0.67       286
# weighted avg       0.73      0.69      0.67       286
#
#
# CR: (0.7317311808230906, 0.6853146853146853, 0.6687258687258687, None)
#
# Confusion matrix:
#  [[ 66  77]
#  [ 13 130]]
#
# _______________________
#
#
# Recall: 0.909
#  Precision: 0.628
#  F1: 0.743
#  FPR: 0.538
#  Accuracy: 68.531
#  ROC_AUC: 0.685
# ***testing on test set***
# Accuracy: 0.6944444444444444
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.47      0.61        36
#            1       0.63      0.92      0.75        36
#
#     accuracy                           0.69        72
#    macro avg       0.74      0.69      0.68        72
# weighted avg       0.74      0.69      0.68        72
#
#
# CR: (0.7423076923076923, 0.6944444444444444, 0.6785714285714286, None)
#
# Confusion matrix:
#  [[17 19]
#  [ 3 33]]
#
# _______________________
#
#
#  Accuracy: 69.444
#  Precision: 0.635
#  Recall: 0.917
#  F1: 0.750
#  FPR: 0.528
#  ROC_AUC: 0.694
# Accuracy: 0.6944444444444444
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.47      0.61        36
#            1       0.63      0.92      0.75        36
#
#     accuracy                           0.69        72
#    macro avg       0.74      0.69      0.68        72
# weighted avg       0.74      0.69      0.68        72
#
#
# CR: (0.7423076923076923, 0.6944444444444444, 0.6785714285714286, None)
#
# Confusion matrix:
#  [[17 19]
#  [ 3 33]]
#
# _______________________
#
#
# Recall: 0.917
#  Precision: 0.635
#  F1: 0.750
#  FPR: 0.528
#  Accuracy: 69.444
#  ROC_AUC: 0.694
# ***testing on test set***
# Accuracy: 0.48284960422163586
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.46      0.63       722
#            1       0.08      0.92      0.14        36
#
#     accuracy                           0.48       758
#    macro avg       0.53      0.69      0.39       758
# weighted avg       0.95      0.48      0.61       758
#
#
# CR: (0.534635240352065, 0.6889427516158818, 0.38679720325901223, None)
#
# Confusion matrix:
#  [[333 389]
#  [  3  33]]
#
# _______________________
#
#
#  Accuracy: 48.285
#  Precision: 0.078
#  Recall: 0.917
#  F1: 0.144
#  FPR: 0.539
#  ROC_AUC: 0.689
# Accuracy: 0.48284960422163586
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.46      0.63       722
#            1       0.08      0.92      0.14        36
#
#     accuracy                           0.48       758
#    macro avg       0.53      0.69      0.39       758
# weighted avg       0.95      0.48      0.61       758
#
#
# CR: (0.534635240352065, 0.6889427516158818, 0.38679720325901223, None)
#
# Confusion matrix:
#  [[333 389]
#  [  3  33]]
#
# _______________________
#
#
# Recall: 0.917
#  Precision: 0.078
#  F1: 0.144
#  FPR: 0.539
#  Accuracy: 48.285
#  ROC_AUC: 0.689
# ***10-fold cross-validation***
# Accuracy: 0.7048192771084337
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.46      0.61       166
#            1       0.64      0.95      0.76       166
#
#     accuracy                           0.70       332
#    macro avg       0.77      0.70      0.69       332
# weighted avg       0.77      0.70      0.69       332
#
#
# CR: (0.7667801096615617, 0.7048192771084337, 0.6866235167206041, None)
#
# Confusion matrix:
#  [[ 77  89]
#  [  9 157]]
#
# _______________________
#
#
#  Accuracy: 70.482
#  Precision: 0.638
#  Recall: 0.946
#  F1: 0.762
#  FPR: 0.536
#  ROC_AUC: 0.705
# Accuracy: 0.7048192771084337
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.46      0.61       166
#            1       0.64      0.95      0.76       166
#
#     accuracy                           0.70       332
#    macro avg       0.77      0.70      0.69       332
# weighted avg       0.77      0.70      0.69       332
#
#
# CR: (0.7667801096615617, 0.7048192771084337, 0.6866235167206041, None)
#
# Confusion matrix:
#  [[ 77  89]
#  [  9 157]]
#
# _______________________
#
#
# Recall: 0.946
#  Precision: 0.638
#  F1: 0.762
#  FPR: 0.536
#  Accuracy: 70.482
#  ROC_AUC: 0.705
# ***testing on test set***
# Accuracy: 0.75
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.52      0.68        42
#            1       0.67      0.98      0.80        42
#
#     accuracy                           0.75        84
#    macro avg       0.81      0.75      0.74        84
# weighted avg       0.81      0.75      0.74        84
#
#
# CR: (0.8143264433357091, 0.75, 0.7365197908887229, None)
#
# Confusion matrix:
#  [[22 20]
#  [ 1 41]]
#
# _______________________
#
#
#  Accuracy: 75.000
#  Precision: 0.672
#  Recall: 0.976
#  F1: 0.796
#  FPR: 0.476
#  ROC_AUC: 0.750
# Accuracy: 0.75
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.52      0.68        42
#            1       0.67      0.98      0.80        42
#
#     accuracy                           0.75        84
#    macro avg       0.81      0.75      0.74        84
# weighted avg       0.81      0.75      0.74        84
#
#
# CR: (0.8143264433357091, 0.75, 0.7365197908887229, None)
#
# Confusion matrix:
#  [[22 20]
#  [ 1 41]]
#
# _______________________
#
#
# Recall: 0.976
#  Precision: 0.672
#  F1: 0.796
#  FPR: 0.476
#  Accuracy: 75.000
#  ROC_AUC: 0.750
# ***testing on test set***
# Accuracy: 0.5222222222222223
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.50      0.67       948
#            1       0.08      0.98      0.15        42
#
#     accuracy                           0.52       990
#    macro avg       0.54      0.74      0.41       990
# weighted avg       0.96      0.52      0.65       990
#
#
# CR: (0.538912795615874, 0.7391500904159132, 0.4079089615931721, None)
#
# Confusion matrix:
#  [[476 472]
#  [  1  41]]
#
# _______________________
#
#
#  Accuracy: 52.222
#  Precision: 0.080
#  Recall: 0.976
#  F1: 0.148
#  FPR: 0.498
#  ROC_AUC: 0.739
# Accuracy: 0.5222222222222223
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.50      0.67       948
#            1       0.08      0.98      0.15        42
#
#     accuracy                           0.52       990
#    macro avg       0.54      0.74      0.41       990
# weighted avg       0.96      0.52      0.65       990
#
#
# CR: (0.538912795615874, 0.7391500904159132, 0.4079089615931721, None)
#
# Confusion matrix:
#  [[476 472]
#  [  1  41]]
#
# _______________________
#
#
# Recall: 0.976
#  Precision: 0.080
#  F1: 0.148
#  FPR: 0.498
#  Accuracy: 52.222
#  ROC_AUC: 0.739

# %%
df_metrics
# Out:
#                 set                    section   tn   fp  fn   tp    recall  \
# 0    balanced train        Parties & Operation  112   60  63  110  0.635838
# 1     balanced test        Parties & Operation   30   14  13   30  0.697674
# 2   imbalanced test        Parties & Operation  653  394  13   30  0.697674
# 3    balanced train  Concentration & Dimension  100   90  76  114  0.600000
# 4     balanced test  Concentration & Dimension   29   19  23   25  0.520833
# 5   imbalanced test  Concentration & Dimension  664  440  23   25  0.520833
# 6    balanced train          Market Definition   66   77  13  130  0.909091
# 7     balanced test          Market Definition   17   19   3   33  0.916667
# 8   imbalanced test          Market Definition  333  389   3   33  0.916667
# 9    balanced train     Competitive Assessment   77   89   9  157  0.945783
# 10    balanced test     Competitive Assessment   22   20   1   41  0.976190
# 11  imbalanced test     Competitive Assessment  476  472   1   41  0.976190
#
#     precision   f_score       fpr   accuracy   roc_auc     n
# 0    0.647059  0.641399  0.348837  64.347826  0.643500   345
# 1    0.681818  0.689655  0.318182  68.965517  0.689746    87
# 2    0.070755  0.128480  0.376313  62.660550  0.660681  1090
# 3    0.558824  0.578680  0.473684  56.315789  0.563158   380
# 4    0.568182  0.543478  0.395833  56.250000  0.562500    96
# 5    0.053763  0.097466  0.398551  59.809028  0.561141  1152
# 6    0.628019  0.742857  0.538462  68.531469  0.685315   286
# 7    0.634615  0.750000  0.527778  69.444444  0.694444    72
# 8    0.078199  0.144105  0.538781  48.284960  0.688943   758
# 9    0.638211  0.762136  0.536145  70.481928  0.704819   332
# 10   0.672131  0.796117  0.476190  75.000000  0.750000    84
# 11   0.079922  0.147748  0.497890  52.222222  0.739150   990

# %%
df_metrics.to_excel('../../../../output/tables/svm_metrics_section_wc.xlsx', index=True)

# %% [markdown]
# ### Confusion matrix and model performance

# %% [markdown]
# ### Feature importance

# %% [markdown]
# Get features for label = 1 and label = 0

# %%
for section_key in section_dict.keys():
    globals()[f"df_features_train1_{section_key}"], globals()[f"df_features_train0_{section_key}"] = get_feature_importance10(globals()[f"df_features_train_{section_key}"])

# %%
for section_key in section_dict.keys():
    # Sort the features by absolute importance for label=1
    globals()[f"df_features_train1_{section_key}"] = globals()[f"df_features_train1_{section_key}"].sort_values(by='abs_importance', ascending=False)
    globals()[f"df_features_train1_top10_{section_key}"] = globals()[f"df_features_train1_{section_key}"].nlargest(20, 'abs_importance')
    globals()[f"df_features_train1_top10_{section_key}"] = globals()[f"df_features_train1_top10_{section_key}"].sort_values('importance', ascending=True)

    # Sort the features by absolute importance for label=0
    globals()[f"df_features_train0_{section_key}"] = globals()[f"df_features_train0_{section_key}"].sort_values(by='abs_importance', ascending=False)
    globals()[f"df_features_train0_top10_{section_key}"] = globals()[f"df_features_train0_{section_key}"].nlargest(20, 'abs_importance')

    # Create a combined bar chart
    fig, ax = plt.subplots(figsize=(12, 8))
    ax.barh(globals()[f"df_features_train0_top10_{section_key}"]['feature'], globals()[f"df_features_train0_top10_{section_key}"]['importance'], color='darkblue', label='With Conditions=0')
    ax.barh(globals()[f"df_features_train1_top10_{section_key}"]['feature'], globals()[f"df_features_train1_top10_{section_key}"]['importance'], color='maroon', label='With Conditions=1')
    ax.set_xlabel('Importance')
    ax.set_ylabel('Features')
    ax.set_title(str(section_dict[section_key])+ ': Top 20 Features by Importance for With Conditions =0 and =1')
    ax.legend()
    plt.xticks(rotation=90)
    #plt.show()

    plt.savefig('../../../../output/figures/svm_section_' + str(section_key) + '.png', bbox_inches='tight')

# %%
for section_key in section_dict.keys():
    globals()[f"df_features_train_{section_key}"].to_excel('../../../../output/tables/features_svm_train_wc_' + str(section_key) + '.xlsx', index=True)
